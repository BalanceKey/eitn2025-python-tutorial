# %% [markdown]
# # Getting started on Git
#
# If you don't have one, set up a free GitHub account here: https://github.com/
#
# Also, install Git on your machine here: https://github.com/git-guides/install-git
#
# ### Git is useful for group projects
# ![alt text](images/Git-distributed-development_0.png "Title")

# %% [markdown]
# This is a very good tutorial:
#
# https://rogerdudler.github.io/git-guide/
